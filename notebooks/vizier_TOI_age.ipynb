# %% [markdown]
# ## TOI ages from vizier

# %%
#so just import from another directory
import sys
sys.path.insert(0, '../code')

# %%
from kenmon import get_tois_data

df = get_tois_data()
df.tail(3)
# Out:
#          TIC ID      TOI    Previous CTOI  Master  SG1A  SG1B  SG2  SG3  SG4  \
# 6259  422159302  7183.01              NaN       3     4     3    3    1    4
# 6260  426956677  7184.01              NaN       2     4     2    2    1    4
# 6261   77490011  7185.01  TIC 77490011.01       1     4     1    1    1    4
#
#       SG5  ...  Stellar Metallicity err  Stellar Mass (M_Sun)  \
# 6259    4  ...                      NaN                   NaN
# 6260    4  ...                    0.028              0.990000
# 6261    4  ...                      NaN              0.202644
#
#       Stellar Mass (M_Sun) err                  Sectors  \
# 6259                       NaN  16,17,24,57,76,77,83,84
# 6260                  0.127349                    57,84
# 6261                  0.020103                       85
#
#       Date TOI Alerted (UTC)  Date TOI Updated (UTC)        Date Modified  \
# 6259              2025-01-09              2025-01-09  2025-01-16 12:03:02
# 6260              2025-01-09              2025-01-09  2025-01-16 12:02:59
# 6261              2025-01-09              2025-01-09  2025-01-16 12:03:02
#
#                                                Comments      ra_deg    dec_deg
# 6259                    weak transit shape; possibly SV  335.623083  58.083092
# 6260                                            low SNR    2.494583  18.773831
# 6261  possible odd-even; also a CTOI from Marco Mont...   42.823792  30.281303
#
# [3 rows x 64 columns]

# %% [raw]
# df.query("TOI==6902.01").Comments

# %%
df.shape
# Out:
# (6262, 64)

# %%
d = df.query("TOI==700.01").squeeze()
d
# Out:
# TIC ID                                 150428135
# TOI                                       700.01
# Previous CTOI                                NaN
# Master                                         2
# SG1A                                           5
#                                    ...
# Date TOI Updated (UTC)                2024-02-14
# Date Modified                2024-02-17 12:12:31
# Comments                  TOI-700 c / TOI-700.01
# ra_deg                                 97.095708
# dec_deg                               -65.578614
# Name: 504, Length: 64, dtype: object

# %%
d.ra_deg, d.dec_deg
# Out:
# (97.09570833333332, -65.57861388888888)

# %%
from kenmon import Target

t = Target(d.ra_deg, d.dec_deg)
p = t.query_vizier_param(param="age")
p
# Out:
# WARNING: UnitsWarning: Unit 'e' not supported by the VOUnit standard.  [astropy.units.format.vounit]
# WARNING: UnitsWarning: Unit 'x' not supported by the VOUnit standard.  [astropy.units.format.vounit]
# WARNING: UnitsWarning: Unit 'Earth' not supported by the VOUnit standard.  [astropy.units.format.vounit]
# WARNING: UnitsWarning: Unit 'bar' not supported by the VOUnit standard. Did you mean 1e-28m**2, Ba (deprecated), aR, barn (deprecated) or g.cm**-1.s**-2? [astropy.units.format.vounit]
# Found 1 references in Vizier using `age`.
# {'J/A+A/669/A104/catalog:age': 0.100001}

# %%
p.get('J/A+A/669/A104/catalog:age')
# Out:
# 0.100001

# %%
from kenmon import Target

t = Target(d.ra_deg, d.dec_deg)
# q = r"^(?!.*image).*age.*$"
q = 'age'
t.query_vizier_param(param=q, use_regex=True)
# Out:
# WARNING: UnitsWarning: Unit 'e' not supported by the VOUnit standard.  [astropy.units.format.vounit]
# WARNING: UnitsWarning: Unit 'x' not supported by the VOUnit standard.  [astropy.units.format.vounit]
# WARNING: UnitsWarning: Unit 'Earth' not supported by the VOUnit standard.  [astropy.units.format.vounit]
# Found 7 references in Vizier using `age`.
# WARNING: UnitsWarning: Unit 'bar' not supported by the VOUnit standard. Did you mean 1e-28m**2, Ba (deprecated), aR, barn (deprecated) or g.cm**-1.s**-2? [astropy.units.format.vounit]
# {'I/355/paramp:Age-Flame': nan,
#  'I/355/paramsup:Age-Flame': nan,
#  'J/A+A/662/A15/table1:Age': 1.5,
#  'J/A+A/669/A104/catalog:age': 0.100001,
#  'J/AJ/167/159/table3:Age': 5.8439,
#  'J/AJ/167/159/table3:E_Age': 0.05755,
#  'J/AJ/167/159/table3:e_Age': -0.06236}

# %%
from tqdm import tqdm

# regex_query = r"^(?!.*image).*age.*$"
regex_query = 'age'

for i,row in tqdm(df.iterrows()):
    t = Target(row.ra_deg, row.dec_deg)
    p = t.query_vizier_param(param=regex_query, use_regex=True)
    data[row.TOI] = p
    break
# Out:
# 0it [00:00, ?it/s]WARNING: UnitsWarning: Unit 'x' not supported by the VOUnit standard.  [astropy.units.format.vounit]
# WARNING: UnitsWarning: Unit 'Earth' not supported by the VOUnit standard.  [astropy.units.format.vounit]
# 0it [00:00, ?it/s]
# Found 16 references in Vizier using `age`.

# %% [markdown]
# ## runtime test

# %% [markdown]
# ## parallel run

# %%
df = get_tois_data()

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from concurrent.futures import ProcessPoolExecutor, as_completed
from kenmon import Target
import time
import random

# regex_query = r"^(?!.*image).*age.*$"
regex_query = 'age'

def process_row(row, max_retries=3, timeout=30):
    """Process each row to query Vizier with retries, rate limiting, and timeouts."""
    t = Target(row.ra_deg, row.dec_deg)
    
    for attempt in range(max_retries):
        try:
            # Apply rate limiting with random sleep to prevent server overload
            time.sleep(random.uniform(0.5, 2.0))  
            
            p = t.query_vizier_param(param=regex_query, use_regex=True)
            return row.TOI, p
        except Exception as e:
            print(f"Attempt {attempt+1} failed for TOI {row.TOI}: {e}")
            time.sleep(2 ** attempt)  # Exponential backoff
    return row.TOI, f"Failed after {max_retries} retries"

# Parallel execution with limited workers
data = {}
max_workers = min(4, len(df))  # Adjust based on server limits

with ProcessPoolExecutor(max_workers=max_workers) as executor:
    futures = {executor.submit(process_row, row): row for _, row in df.iterrows()}
    
    for future in tqdm(as_completed(futures), total=len(futures)):
        toi, result = future.result()
        data[toi] = result

# %%
import pandas as pd

data_df = pd.DataFrame(data)
data_df.index.unique()
# Out:
# Index(['I/355/paramp:Age-Flame', 'I/355/paramsup:Age-Flame',
#        'I/360/goldf:Age-F', 'I/360/goldf:Age-FS', 'J/ApJ/919/138/table1:Age',
#        'J/ApJ/919/138/table1:E_Age', 'J/ApJ/919/138/table1:e_Age',
#        'J/A+A/669/A104/catalog:age', 'J/A+A/673/A155/galahdr3:Age50',
#        'J/A+A/674/A39/table8:AgeStar',
#        ...
#        'J/A+A/604/A108/rave_dr5:logAgeMean',
#        'J/A+A/604/A108/rave_dr5:e_logAgeMean', 'J/A+A/693/L4/tablea1:stAge',
#        'J/AJ/167/159/table2:Age', 'J/AJ/167/159/table2:E_Age',
#        'J/AJ/167/159/table2:e_Age', 'J/MNRAS/533/1290/table1:Age',
#        'J/A+A/692/A243/mrs:Agel', 'J/A+A/692/A243/mrs:Agec',
#        'J/A+A/692/A243/lrs:Age'],
#       dtype='object', length=389)

# %% [markdown]
# ## all

# %%
data_df.T.dropna(how='all', axis=0).sort_values(by='I/355/paramp:Age-Flame', ascending=True)
# Out:
#         I/355/paramp:Age-Flame I/355/paramsup:Age-Flame I/360/goldf:Age-F  \
# 1208.01                    0.2                 0.930752          0.200482
# 1208.02                    0.2                 0.930752          0.200482
# 1208.03                    0.2                 0.930752          0.200482
# 1434.01                  0.201                      NaN               NaN
# 2783.01                  0.202                      NaN               NaN
# ...                        ...                      ...               ...
# 7151.01                    NaN                   4.1098               NaN
# 7148.01                    NaN                 9.576713               NaN
# 7158.01                    NaN                      NaN               NaN
# 7160.01                    NaN                      NaN               NaN
# 7165.01                    NaN                      NaN               NaN
#
#         I/360/goldf:Age-FS J/ApJ/919/138/table1:Age  \
# 1208.01                NaN                      NaN
# 1208.02                NaN                      NaN
# 1208.03                NaN                      NaN
# 1434.01                NaN                      NaN
# 2783.01                NaN                      NaN
# ...                    ...                      ...
# 7151.01                NaN                      NaN
# 7148.01                NaN                      NaN
# 7158.01                NaN                      NaN
# 7160.01                NaN                      NaN
# 7165.01                NaN                      5.7
#
#         J/ApJ/919/138/table1:E_Age J/ApJ/919/138/table1:e_Age  \
# 1208.01                        NaN                        NaN
# 1208.02                        NaN                        NaN
# 1208.03                        NaN                        NaN
# 1434.01                        NaN                        NaN
# 2783.01                        NaN                        NaN
# ...                            ...                        ...
# 7151.01                        NaN                        NaN
# 7148.01                        NaN                        NaN
# 7158.01                        NaN                        NaN
# 7160.01                        NaN                        NaN
# 7165.01                       2.11                       1.29
#
#         J/A+A/669/A104/catalog:age J/A+A/673/A155/galahdr3:Age50  \
# 1208.01                   1.100806                           NaN
# 1208.02                   1.100806                           NaN
# 1208.03                   1.100806                           NaN
# 1434.01                        NaN                           NaN
# 2783.01                        NaN                           NaN
# ...                            ...                           ...
# 7151.01                        NaN                           NaN
# 7148.01                        NaN                           NaN
# 7158.01                        NaN                           NaN
# 7160.01                        NaN                           NaN
# 7165.01                        NaN                           NaN
#
#         J/A+A/674/A39/table8:AgeStar  ... J/A+A/604/A108/rave_dr5:logAgeMean  \
# 1208.01                          NaN  ...                                NaN
# 1208.02                          NaN  ...                                NaN
# 1208.03                          NaN  ...                                NaN
# 1434.01                          NaN  ...                                NaN
# 2783.01                          NaN  ...                                NaN
# ...                              ...  ...                                ...
# 7151.01                          NaN  ...                                NaN
# 7148.01                          NaN  ...                                NaN
# 7158.01                          NaN  ...                                NaN
# 7160.01                          NaN  ...                                NaN
# 7165.01                          NaN  ...                                NaN
#
#         J/A+A/604/A108/rave_dr5:e_logAgeMean J/A+A/693/L4/tablea1:stAge  \
# 1208.01                                  NaN                        NaN
# 1208.02                                  NaN                        NaN
# 1208.03                                  NaN                        NaN
# 1434.01                                  NaN                        NaN
# 2783.01                                  NaN                        NaN
# ...                                      ...                        ...
# 7151.01                                  NaN                        NaN
# 7148.01                                  NaN                        NaN
# 7158.01                                  NaN                        NaN
# 7160.01                                  NaN                        NaN
# 7165.01                                  NaN                        NaN
#
#         J/AJ/167/159/table2:Age J/AJ/167/159/table2:E_Age  \
# 1208.01                     NaN                       NaN
# 1208.02                     NaN                       NaN
# 1208.03                     NaN                       NaN
# 1434.01                     NaN                       NaN
# 2783.01                     NaN                       NaN
# ...                         ...                       ...
# 7151.01                     NaN                       NaN
# 7148.01                     NaN                       NaN
# 7158.01                     NaN                       NaN
# 7160.01                     NaN                       NaN
# 7165.01                     NaN                       NaN
#
#         J/AJ/167/159/table2:e_Age J/MNRAS/533/1290/table1:Age  \
# 1208.01                       NaN                         NaN
# 1208.02                       NaN                         NaN
# 1208.03                       NaN                         NaN
# 1434.01                       NaN                         NaN
# 2783.01                       NaN                         NaN
# ...                           ...                         ...
# 7151.01                       NaN                         NaN
# 7148.01                       NaN                         NaN
# 7158.01                       NaN                         NaN
# 7160.01                       NaN                         NaN
# 7165.01                       NaN                         NaN
#
#         J/A+A/692/A243/mrs:Agel J/A+A/692/A243/mrs:Agec J/A+A/692/A243/lrs:Age
# 1208.01                     NaN                     NaN                    NaN
# 1208.02                     NaN                     NaN                    NaN
# 1208.03                     NaN                     NaN                    NaN
# 1434.01                     NaN                     NaN                    NaN
# 2783.01                     NaN                     NaN                    NaN
# ...                         ...                     ...                    ...
# 7151.01                     NaN                     NaN                    NaN
# 7148.01                     NaN                     NaN                    NaN
# 7158.01                     NaN                     NaN                    NaN
# 7160.01                     NaN                     NaN                    NaN
# 7165.01                     NaN                     NaN                    NaN
#
# [4930 rows x 389 columns]

# %% [markdown]
# Most ages are in Gyr, some in Myr, some in log10.

# %%
data_df.to_csv('../data/TOI_age_vizier.csv')

# %% [markdown]
# ## load data

# %%
import pandas as pd

data_df = pd.read_csv('../data/TOI_age_vizier.csv', index_col=0)
data_df.head()
# Out:
# /tmp/ipykernel_2345253/3736195865.py:3: DtypeWarning: Columns (4,68,69,70,71,72,73,74,75,82,88,91,94,99,131,171,173,174,176,263,267,268,269,275,282,292,293,303,308,309,310,344,386,391,402,404,445,454,462,463,467,483,579,593,620,734,812,836,838,839,875,889,938,943,1002,1026,1069,1071,1072,1074,1112,1119,1166,1168,1170,1201,1203,1204,1206,1251,1278,1294,1307,1329,1346,1386,1467,1471,1531,1532,1559,1562,1564,1568,1645,1818,3576,3647,3658,3693,3695,3698,3787,4241,4248,4249,4289,4298,4432,4761,4801,4851,4916,4917,4919,4921,4926,4945,4947,5065,5079,5098,5116,5132,5359,5638,5784,5785,5789,5803,5924,5984,6045,6046,6061) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_df = pd.read_csv('../data/TOI_age_vizier.csv', index_col=0)
#                            101.01    103.01    104.01     102.01     105.01  \
# I/355/paramp:Age-Flame    5.25700  4.343000       NaN      3.674  10.938000
# I/355/paramsup:Age-Flame      NaN  2.109727  3.198016  1.9911742   7.112666
# I/360/goldf:Age-F         5.25653       NaN       NaN  3.6736262        NaN
# I/360/goldf:Age-FS            NaN       NaN       NaN        NaN        NaN
# J/ApJ/919/138/table1:Age  4.89000       NaN       NaN        NaN   5.620000
#
#                             107.01  106.01  109.01    110.01  108.01  ...  \
# I/355/paramp:Age-Flame    4.136000   1.829     NaN  7.222000  13.261  ...
# I/355/paramsup:Age-Flame  3.843425     NaN     NaN  2.565268     NaN  ...
# I/360/goldf:Age-F              NaN     NaN     NaN       NaN     NaN  ...
# I/360/goldf:Age-FS             NaN     NaN     NaN       NaN     NaN  ...
# J/ApJ/919/138/table1:Age       NaN     NaN     NaN  2.940000   1.590  ...
#
#                           7176.01   7177.01  7178.01   7179.01   7182.01  \
# I/355/paramp:Age-Flame        NaN  7.489000    5.736  5.842000  4.803000
# I/355/paramsup:Age-Flame      NaN       NaN      NaN  5.661383  8.089615
# I/360/goldf:Age-F             NaN  7.489475      NaN       NaN  4.803039
# I/360/goldf:Age-FS            NaN       NaN      NaN       NaN       NaN
# J/ApJ/919/138/table1:Age      NaN       NaN      NaN       NaN       NaN
#
#                            7181.01   7180.01  7183.01   7184.01  7185.01
# I/355/paramp:Age-Flame    3.836000  7.770000      NaN  2.597000      NaN
# I/355/paramsup:Age-Flame  3.873336  3.261123      NaN  0.886076      NaN
# I/360/goldf:Age-F              NaN  7.769972      NaN  2.596616      NaN
# I/360/goldf:Age-FS             NaN       NaN      NaN       NaN      NaN
# J/ApJ/919/138/table1:Age       NaN       NaN      NaN       NaN      NaN
#
# [5 rows x 6262 columns]

# %%
refs = {}
for i in data_df.index:
    count=data_df.loc[i].dropna().shape
    refs[i] = count

# %%
refs = pd.Series(refs).sort_values(ascending=False)
refs.head(20)
# Out:
# I/355/paramp:Age-Flame               (3944,)
# J/A+A/669/A104/catalog:age           (2528,)
# I/355/paramsup:Age-Flame             (2212,)
# I/360/goldf:Age-F                     (857,)
# J/A+A/673/A155/lamostl7:Age50         (302,)
# J/other/Nat/586.528/table1:Tage       (287,)
# J/A+A/671/A16/table9:plate-image      (187,)
# J/A+A/671/A16/table8:plate-image      (186,)
# J/MNRAS/445/4395/tablea1:Age          (151,)
# J/other/Nat/586.528/table1:e_Tage     (137,)
# J/ApJ/835/61/table4:LogAge            (122,)
# J/A+A/673/A155/ravedr6:Age50          (117,)
# J/A+A/673/A155/apogee17:Age50         (110,)
# VII/293/catalog:log10Age              (110,)
# J/ApJ/919/138/table1:E_Age            (104,)
# J/ApJ/919/138/table1:e_Age            (104,)
# J/ApJ/919/138/table1:Age              (104,)
# J/AJ/164/26/table1:Age                 (98,)
# J/MNRAS/422/2024/tables:Age            (98,)
# J/A+A/673/A155/lamostm7:Age50          (98,)
# dtype: object

# %% [markdown]
# https://cdsarc.cds.unistra.fr/viz-bin/cat/I/355

# %%
# Age (Gyr) of the star from FLAME using stellar models
age_flame = data_df.loc['I/355/paramp:Age-Flame']
age_flame.sort_values()
# Out:
# 1208.01      0.2
# 1208.02      0.2
# 1208.03      0.2
# 1434.01    0.201
# 2783.01    0.202
#            ...
# 7166.01      NaN
# 7173.01      NaN
# 7176.01      NaN
# 7183.01      NaN
# 7185.01      NaN
# Name: I/355/paramp:Age-Flame, Length: 6262, dtype: object

# %% [markdown]
# https://cdsarc.cds.unistra.fr/viz-bin/cat/J/A+A/669/A104

# %%
age_gaia = data_df.loc['J/A+A/669/A104/catalog:age']
age_gaia.sort_values()
# Out:
# 1693.01         0.1
# 700.04     0.100001
# 700.03     0.100001
# 700.02     0.100001
# 700.01     0.100001
#              ...
# 7181.01         NaN
# 7180.01         NaN
# 7183.01         NaN
# 7184.01         NaN
# 7185.01         NaN
# Name: J/A+A/669/A104/catalog:age, Length: 6262, dtype: object

# %% [raw]
# # some other age like age_spec, age_specjhk, age_specjhkg is missing
# # see also J/A+A/673/A155/ravedr6:Age50, J/A+A/673/A155/apogee17:Age50

# %% [markdown]
# https://cdsarc.cds.unistra.fr/viz-bin/cat/J/A+A/673/A155

# %%
# there are Age16 and Age84 in table but not shown by default
age_lamost7 = data_df.loc['J/A+A/673/A155/lamostl7:Age50']
age_lamost7.sort_values()
# Out:
# 5439.01    0.425001
# 5270.01    0.726045
# 5066.01     0.82253
# 7088.01    0.824189
# 6395.01    0.826276
#              ...
# 7181.01         NaN
# 7180.01         NaN
# 7183.01         NaN
# 7184.01         NaN
# 7185.01         NaN
# Name: J/A+A/673/A155/lamostl7:Age50, Length: 6262, dtype: object

# %% [markdown]
# https://cdsarc.cds.unistra.fr/viz-bin/cat/J/ApJ/898/27

# %%
data_df.loc['J/ApJ/898/27/table2:_50Age2'].dropna()
# Out:
# 1860.01    338.0
# Name: J/ApJ/898/27/table2:_50Age2, dtype: object

# %% [raw]
# # using Li; in Myr
# cols = ['J/ApJ/898/27/table2:_16Age2','J/ApJ/898/27/table2:_50Age2','J/ApJ/898/27/table2:_84Age2']
# age_baffles_li = data_df.loc[cols].dropna(axis=1).T.apply(lambda x: x/1e3)
# age_baffles_li.sort_values(by='J/ApJ/898/27/table2:_50Age2')

# %%
# using rhk; in Myr
cols = ['J/ApJ/898/27/table2:_16Age1','J/ApJ/898/27/table2:_50Age1','J/ApJ/898/27/table2:_84Age1']
# convert 
age_baffles_rhk = data_df.loc[cols].dropna(axis=1).T.apply(lambda x: x/1e3)
age_baffles_rhk.sort_values(by='J/ApJ/898/27/table2:_50Age1')
# Out:
#         J/ApJ/898/27/table2:_16Age1 J/ApJ/898/27/table2:_50Age1  \
# 200.01                       0.0177                      0.0888
# 1860.01                       0.103                       0.285
# 1726.01                       0.199                        0.49
# 1726.02                       0.199                        0.49
# 5082.01                       0.273                       0.641
# 179.01                        0.293                       0.681
# 2666.01                       0.382                       0.858
# 6902.01                       0.449                       0.986
# 5140.01                       0.991                        1.98
# 4537.01                         1.1                        2.17
# 2020.01                        1.15                        2.25
# 4568.01                         1.4                         2.7
# 396.01                         1.87                        3.49
# 396.02                         1.87                        3.49
# 396.03                         1.87                        3.49
# 1462.01                        2.08                        3.83
# 141.01                          3.0                        5.27
# 6965.02                        3.15                         5.5
# 6965.01                        3.15                         5.5
# 2128.01                        3.54                        6.08
# 4326.01                        3.74                        6.38
# 652.01                         3.86                        6.55
# 5972.01                        4.08                        6.85
# 2024.01                         4.6                        7.58
# 1573.01                        5.03                        8.15
# 1821.01                         5.7                        8.95
#
#         J/ApJ/898/27/table2:_84Age1
# 200.01                        0.625
# 1860.01                        1.25
# 1726.01                        1.77
# 1726.02                        1.77
# 5082.01                        2.12
# 179.01                         2.21
# 2666.01                         2.6
# 6902.01                        2.86
# 5140.01                        4.63
# 4537.01                        4.92
# 2020.01                        5.05
# 4568.01                        5.69
# 396.01                         6.71
# 396.02                         6.71
# 396.03                         6.71
# 1462.01                        7.12
# 141.01                         8.59
# 6965.02                         8.8
# 6965.01                         8.8
# 2128.01                        9.31
# 4326.01                        9.59
# 652.01                         9.75
# 5972.01                        10.0
# 2024.01                        10.7
# 1573.01                        11.2
# 1821.01                        11.6

# %% [markdown]
# TOI-1726: https://ui.adsabs.harvard.edu/abs/2023A%26A...672A.126D/abstract

# %% [markdown]
# ## reliable

# %%
cols = ['I/355/paramp:Age-Flame',
        'J/A+A/669/A104/catalog:age',
        'J/A+A/673/A155/lamostl7:Age50',
        'J/A+A/673/A155/ravedr6:Age50', 
        'J/A+A/673/A155/apogee17:Age50',
        'J/ApJ/898/27/table2:_50Age1'
       ]
# drop rows with NaN
data_df2 = data_df.loc[cols].T.astype(float)
data_df2['J/ApJ/898/27/table2:_50Age1'] = data_df2['J/ApJ/898/27/table2:_50Age1'].apply(lambda x: x/1e3)
data_df2 = data_df2.dropna(how='all', axis=0)
data_df2
# Out:
#          I/355/paramp:Age-Flame  J/A+A/669/A104/catalog:age  \
# 101.01                    5.257                         NaN
# 103.01                    4.343                    2.469392
# 104.01                      NaN                    3.349768
# 102.01                    3.674                    3.248167
# 105.01                   10.938                    5.051802
# ...                         ...                         ...
# 7179.01                   5.842                         NaN
# 7182.01                   4.803                         NaN
# 7181.01                   3.836                         NaN
# 7180.01                   7.770                         NaN
# 7184.01                   2.597                         NaN
#
#          J/A+A/673/A155/lamostl7:Age50  J/A+A/673/A155/ravedr6:Age50  \
# 101.01                             NaN                           NaN
# 103.01                             NaN                           NaN
# 104.01                             NaN                      3.211976
# 102.01                             NaN                           NaN
# 105.01                             NaN                           NaN
# ...                                ...                           ...
# 7179.01                            NaN                           NaN
# 7182.01                            NaN                           NaN
# 7181.01                            NaN                           NaN
# 7180.01                            NaN                           NaN
# 7184.01                            NaN                           NaN
#
#          J/A+A/673/A155/apogee17:Age50  J/ApJ/898/27/table2:_50Age1
# 101.01                             NaN                          NaN
# 103.01                             NaN                          NaN
# 104.01                             NaN                          NaN
# 102.01                             NaN                          NaN
# 105.01                             NaN                          NaN
# ...                                ...                          ...
# 7179.01                            NaN                          NaN
# 7182.01                            NaN                          NaN
# 7181.01                            NaN                          NaN
# 7180.01                            NaN                          NaN
# 7184.01                            NaN                          NaN
#
# [4673 rows x 6 columns]

# %% [raw]
# (data_df2<1).all(axis=1).sum()

# %%
import numpy as np

data_df_median = data_df2.apply(lambda x: np.nanmedian(x), axis=1)
data_df_median.dropna().shape
# Out:
# (4673,)

# %%
data_df2_mean = data_df2.mean(axis=1)
data_df2_mean.dropna().shape
# Out:
# (4673,)

# %%
short_list = data_df2_mean[data_df2_mean<1].sort_values()
short_list = set([int(str(i).split('.')[0]) for i in list(short_list.index)])
short_list
# Out:
# {137,
#  159,
#  199,
#  231,
#  233,
#  277,
#  314,
#  386,
#  451,
#  503,
#  508,
#  522,
#  540,
#  579,
#  602,
#  616,
#  621,
#  624,
#  626,
#  629,
#  642,
#  671,
#  692,
#  700,
#  703,
#  761,
#  769,
#  772,
#  779,
#  782,
#  815,
#  863,
#  885,
#  905,
#  952,
#  986,
#  989,
#  990,
#  991,
#  1027,
#  1044,
#  1059,
#  1105,
#  1125,
#  1139,
#  1150,
#  1151,
#  1196,
#  1198,
#  1208,
#  1218,
#  1224,
#  1239,
#  1311,
#  1322,
#  1327,
#  1337,
#  1355,
#  1364,
#  1382,
#  1409,
#  1418,
#  1434,
#  1468,
#  1487,
#  1489,
#  1518,
#  1531,
#  1533,
#  1564,
#  1599,
#  1641,
#  1687,
#  1693,
#  1801,
#  1803,
#  1853,
#  1901,
#  1916,
#  1924,
#  1926,
#  1927,
#  1976,
#  2051,
#  2063,
#  2064,
#  2080,
#  2085,
#  2095,
#  2098,
#  2123,
#  2210,
#  2241,
#  2279,
#  2283,
#  2327,
#  2394,
#  2431,
#  2434,
#  2435,
#  2448,
#  2457,
#  2481,
#  2484,
#  2495,
#  2504,
#  2541,
#  2551,
#  2552,
#  2577,
#  2592,
#  2594,
#  2618,
#  2666,
#  2672,
#  2692,
#  2757,
#  2783,
#  2809,
#  2813,
#  2831,
#  2832,
#  2841,
#  2847,
#  2854,
#  2869,
#  2872,
#  2898,
#  2901,
#  2914,
#  2945,
#  2953,
#  2954,
#  2961,
#  2979,
#  3009,
#  3029,
#  3045,
#  3047,
#  3051,
#  3067,
#  3068,
#  3076,
#  3091,
#  3104,
#  3139,
#  3143,
#  3152,
#  3170,
#  3178,
#  3182,
#  3186,
#  3190,
#  3193,
#  3201,
#  3206,
#  3219,
#  3231,
#  3242,
#  3304,
#  3341,
#  3363,
#  3371,
#  3374,
#  3405,
#  3411,
#  3418,
#  3475,
#  3496,
#  3502,
#  3503,
#  3513,
#  3530,
#  3543,
#  3559,
#  3571,
#  3583,
#  3587,
#  3589,
#  3603,
#  3640,
#  3652,
#  3678,
#  3679,
#  3717,
#  3770,
#  3771,
#  3785,
#  3933,
#  3935,
#  3944,
#  3982,
#  3995,
#  4047,
#  4072,
#  4097,
#  4121,
#  4144,
#  4200,
#  4220,
#  4264,
#  4342,
#  4365,
#  4373,
#  4384,
#  4408,
#  4447,
#  4467,
#  4501,
#  4543,
#  4586,
#  4588,
#  4597,
#  4604,
#  4608,
#  4609,
#  4619,
#  4643,
#  4743,
#  4769,
#  4793,
#  4841,
#  4847,
#  4848,
#  4872,
#  4904,
#  4926,
#  4933,
#  4939,
#  4961,
#  4963,
#  5012,
#  5026,
#  5031,
#  5033,
#  5034,
#  5038,
#  5114,
#  5139,
#  5168,
#  5180,
#  5186,
#  5197,
#  5222,
#  5240,
#  5264,
#  5270,
#  5348,
#  5387,
#  5391,
#  5401,
#  5415,
#  5416,
#  5421,
#  5439,
#  5473,
#  5492,
#  5530,
#  5585,
#  5635,
#  5655,
#  5697,
#  5730,
#  5736,
#  5747,
#  5809,
#  5816,
#  5845,
#  5858,
#  5957,
#  5996,
#  6025,
#  6095,
#  6156,
#  6198,
#  6214,
#  6215,
#  6231,
#  6245,
#  6291,
#  6307,
#  6312,
#  6313,
#  6314,
#  6328,
#  6336,
#  6371,
#  6395,
#  6473,
#  6474,
#  6489,
#  6494,
#  6496,
#  6514,
#  6520,
#  6522,
#  6533,
#  6537,
#  6539,
#  6544,
#  6582,
#  6610,
#  6611,
#  6624,
#  6633,
#  6634,
#  6635,
#  6672,
#  6698,
#  6710,
#  6716,
#  6754,
#  6763,
#  6765,
#  6848,
#  6907,
#  6915,
#  6944,
#  6998,
#  7053,
#  7058,
#  7074,
#  7089,
#  7092,
#  7098,
#  7102,
#  7120,
#  7121,
#  7130,
#  7155,
#  7157,
#  7161,
#  7163,
#  7164,
#  7171,
#  7175}
